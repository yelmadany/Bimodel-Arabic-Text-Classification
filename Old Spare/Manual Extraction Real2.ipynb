# %% [markdown]
# <h1>Manual Feature Extraction + Processing</h1>

# %% [markdown]
# <h2>Libraries</h2>

# %%
import cv2
import numpy as np
from scipy.signal import find_peaks
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score
from bayes_opt import BayesianOptimization
import os
import pandas as pd
import cv2
import numpy as np
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %% [markdown]
# <h2> Processing </h2>

# %%
def preprocess_image(img):
    # Load image
    #img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    if len(img.shape) == 3:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Noise removal with median filter
    img = cv2.medianBlur(img, 3)
    
    # Binarize image using Otsu's threshold
    _, binary_img = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    #binary_image_3_channels = cv2.cvtColor(binary_img, cv2.COLOR_GRAY2BGR)  
    
    return binary_img

def dilate_image(image):
    #
    kernel = np.ones((5,5), np.uint8)

    #
    dilated_img = cv2.dilate(image, kernel, iterations=1)

    return dilated_img

# %% [markdown]
# <h2>Pen Pressure<h2>

# %%
#Feature 1: Pen Pressure: Calculate the Mean and STD (2 Features)

def pen_pressure_features(image):
    #image = cv2.imread(image, cv2.IMREAD_GRAYSCALE)

    #Mean
    mean_intensity = np.mean(image) 

    #STD
    std_intensity = np.std(image) 

    return mean_intensity, std_intensity

# %% [markdown]
# <h2>Left and Right Margins<h2>

# %%
#Feature 2: Left and Right Margins for the first 200 rows (400 features)

def extract_margins(image):
    #Left Margin Code
    def left_margin(image):
        left_margins = []
        for i in range(200):  # Considering the first 200 rows
            row = image[i]
            first_black_pixel_index = np.argmax(row == 0) #extract the first black feature from the left
            left_margins.append((first_black_pixel_index,i))
        return left_margins

    #Right Margin Code
    def right_margin(image):
        right_margins = []
        width = image.shape[1]
        for i in range(200):  # Considering the first 200 rows
            row = image[i]
            last_black_pixel_index = width - np.argmax(np.flipud(row) == 0) #extract the last black pixel
            right_margin = width - last_black_pixel_index 
            right_margins.append((right_margin, i))
        return right_margins


    # Dilate the image
    dilated_img = dilate_image(image)

    # Extract margin features
    left_margin_features = left_margin(dilated_img)
    right_margin_features = right_margin(dilated_img)

    return left_margin_features, right_margin_features

# %% [markdown]
# <h2>Handwriting Irregularity</h2>

# %%
def test_handwriting_irregularity(image):
    def horizontal_projection_profile(image):
        # Considering only the first 700 rows
        limited_image = image[:700]

        # Horizontal projection: Summing up values along each row
        projection_profile = np.sum(limited_image, axis=1)
        
        return projection_profile


    def find_peaks_and_valleys(projection_profile):

        peaks, _ = find_peaks(projection_profile)

        valleys, _ = find_peaks(-projection_profile)
        
        return peaks, valleys
    
    def standardize_projection_profile(profile, desired_length=700):
        if len(profile) > desired_length:
            return profile[:desired_length]
        elif len(profile) < desired_length:
            return np.pad(profile, (0, desired_length - len(profile)), 'constant')
        return profile
        
    # Preprocess and dilate the image
    dilated_img = dilate_image(image)

    # Calculate horizontal projection profile
    projection_profile = horizontal_projection_profile(dilated_img)

    # Find peaks and valleys
    #peaks, valleys = find_peaks_and_valleys(projection_profile)

    standardized_profile = standardize_projection_profile(projection_profile)
    return standardized_profile

# %% [markdown]
# <h2>Feature Extraction<h2>

# %%
def extract_features(image):
    pp_features = np.array(pen_pressure_features(image)).flatten()  # Flatten to ensure 1D
    hi_features = test_handwriting_irregularity(image).flatten()    # Flatten
    left_margin_features = np.array(extract_margins(image)[0]).flatten()  # Flatten
    right_margin_features = np.array(extract_margins(image)[1]).flatten() # Flatten


    # Concatenate all flattened 1D arrays
    combined_features = np.concatenate([pp_features, hi_features, left_margin_features, right_margin_features])

    return combined_features

# %% [markdown]
# <h1>Image Loading<h1>

# %%
updated_excel_file = './updated_excel_file2.xlsx'
data = pd.read_excel(updated_excel_file, usecols=range(5))  # Load only the first 5 columns
width = height = 500
batch_size = 32


def load_images_and_labels(file_names_column, age_column, start_idx, end_idx):
    features_batch = []
    labels_batch = []
    
    for index in range(start_idx, end_idx):
        updated_excel_file = './updated_excel_file2.xlsx'
        data = pd.read_excel(updated_excel_file)  # Load the first 8 columns
        row = data.iloc[index]
        file_name = row[file_names_column]
        age = row[age_column]

        if pd.notnull(age) and pd.notnull(file_name):
            image = cv2.imread(os.path.join('./images', file_name))
            image = preprocess_image(image)
            # image = cv2.resize(image, (width, height))  # Uncomment if resizing is needed
            all_features = extract_features(image)  
            features_batch.append(all_features)
            labels_batch.append(age)

    labels_batch = to_categorical(labels_batch, num_classes=2)  # Confirm this is the desired encoding
    features_batch = np.array(features_batch, dtype='float32')  # Confirm appropriate scaling
    
    return features_batch, labels_batch

# Load all images and labels
all_features = []
all_labels = []

for start_idx in range(0, len(data), batch_size):
    end_idx = min(start_idx + batch_size, len(data))
    features_batch, labels_batch = load_images_and_labels('File Name', 'Gender', start_idx, end_idx)
    
    all_features.append(features_batch)
    all_labels.append(labels_batch)

# Concatenate the batches to create the final arrays
all_features = np.concatenate(all_features)
all_labels = np.concatenate(all_labels)

# Example usage
print(all_features.shape)  # Print the shape of the array containing all features
print(all_labels.shape)  # Print the shape of the array containing all labels
# Out:
# (3840, 1502)
# (3840, 2)

# %%
print(all_features[0])
# Out:
# [2.4090695e+02 5.8267605e+01 4.7073000e+05 ... 1.9800000e+02 4.2200000e+02
#  1.9900000e+02]

# %% [markdown]
# <h1>Classification<h1>

# %% [markdown]
# <h2>NN Classifer<h2>

# %%
def create_ann(input_size, hidden_layer_size):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(hidden_layer_size, activation='relu', input_shape=(input_size,)),
        tf.keras.layers.Dense(2, activation='sigmoid')
    ])
    return model


def compile_model(model):

    optimizer = tf.keras.optimizers.SGD(learning_rate=0.1, momentum=0.9, nesterov=True)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])


def train_ann(model, X_train, y_train, X_val, y_val, epochs, patience):
    # Early stopping callback based on validation loss
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, min_delta=0.0863223)

    # Train the model
    history = model.fit(X_train, y_train, epochs=epochs, validation_data=(X_val, y_val), callbacks=[early_stopping])
    return history


# Define your model
input_size = 1502 
hidden_layer_size = 128  

model = create_ann(input_size, hidden_layer_size)

compile_model(model)

X_train, X_test, y_train, y_test = train_test_split(all_features, all_labels, test_size=0.2, random_state=42)

# Train your model
epochs = 100  # Adjust as per your requirements
patience = 100   # Number of epochs with no improvement on validation loss to stop training
history = train_ann(model, X_train, y_train, X_test, y_test, epochs, patience)
# Out:
# Epoch 1/100
# 96/96 [==============================] - 1s 3ms/step - loss: 32682613768454144.0000 - accuracy: 0.6517 - val_loss: 0.6493 - val_accuracy: 0.6471
# Epoch 2/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6421 - accuracy: 0.6611 - val_loss: 0.6555 - val_accuracy: 0.6471
# Epoch 3/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6437 - accuracy: 0.6611 - val_loss: 0.6622 - val_accuracy: 0.6471
# Epoch 4/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6439 - accuracy: 0.6611 - val_loss: 0.6501 - val_accuracy: 0.6471
# Epoch 5/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6419 - accuracy: 0.6611 - val_loss: 0.6497 - val_accuracy: 0.6471
# Epoch 6/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6423 - accuracy: 0.6611 - val_loss: 0.6543 - val_accuracy: 0.6471
# Epoch 7/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6421 - accuracy: 0.6611 - val_loss: 0.6555 - val_accuracy: 0.6471
# Epoch 8/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6432 - accuracy: 0.6611 - val_loss: 0.6493 - val_accuracy: 0.6471
# Epoch 9/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6424 - accuracy: 0.6611 - val_loss: 0.6493 - val_accuracy: 0.6471
# Epoch 10/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6423 - accuracy: 0.6611 - val_loss: 0.6492 - val_accuracy: 0.6471
# Epoch 11/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6424 - accuracy: 0.6611 - val_loss: 0.6648 - val_accuracy: 0.6471
# Epoch 12/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6432 - accuracy: 0.6611 - val_loss: 0.6526 - val_accuracy: 0.6471
# Epoch 13/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6427 - accuracy: 0.6611 - val_loss: 0.6521 - val_accuracy: 0.6471
# Epoch 14/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.6449 - accuracy: 0.6611 - val_loss: 0.6516 - val_accuracy: 0.6471
# Epoch 15/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6410 - accuracy: 0.6611 - val_loss: 0.6589 - val_accuracy: 0.6471
# Epoch 16/100
# 96/96 [==============================] - 0s 3ms/step - loss: 0.6432 - accuracy: 0.6611 - val_loss: 0.6509 - val_accuracy: 0.6471
# Epoch 17/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6437 - accuracy: 0.6611 - val_loss: 0.6544 - val_accuracy: 0.6471
# Epoch 18/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6440 - accuracy: 0.6611 - val_loss: 0.6502 - val_accuracy: 0.6471
# Epoch 19/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6434 - accuracy: 0.6611 - val_loss: 0.6541 - val_accuracy: 0.6471
# Epoch 20/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6439 - accuracy: 0.6611 - val_loss: 0.6513 - val_accuracy: 0.6471
# Epoch 21/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6426 - accuracy: 0.6611 - val_loss: 0.6492 - val_accuracy: 0.6471
# Epoch 22/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6429 - accuracy: 0.6611 - val_loss: 0.6584 - val_accuracy: 0.6471
# Epoch 23/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6422 - accuracy: 0.6611 - val_loss: 0.6511 - val_accuracy: 0.6471
# Epoch 24/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6438 - accuracy: 0.6611 - val_loss: 0.6492 - val_accuracy: 0.6471
# Epoch 25/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6440 - accuracy: 0.6611 - val_loss: 0.6529 - val_accuracy: 0.6471
# Epoch 26/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6422 - accuracy: 0.6611 - val_loss: 0.6492 - val_accuracy: 0.6471
# Epoch 27/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6418 - accuracy: 0.6611 - val_loss: 0.6632 - val_accuracy: 0.6471
# Epoch 28/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6422 - accuracy: 0.6611 - val_loss: 0.6499 - val_accuracy: 0.6471
# Epoch 29/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6443 - accuracy: 0.6611 - val_loss: 0.6604 - val_accuracy: 0.6471
# Epoch 30/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6446 - accuracy: 0.6611 - val_loss: 0.6516 - val_accuracy: 0.6471
# Epoch 31/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6439 - accuracy: 0.6611 - val_loss: 0.6593 - val_accuracy: 0.6471
# Epoch 32/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6440 - accuracy: 0.6611 - val_loss: 0.6495 - val_accuracy: 0.6471
# Epoch 33/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6433 - accuracy: 0.6611 - val_loss: 0.6504 - val_accuracy: 0.6471
# Epoch 34/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6429 - accuracy: 0.6611 - val_loss: 0.6497 - val_accuracy: 0.6471
# Epoch 35/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6436 - accuracy: 0.6611 - val_loss: 0.6494 - val_accuracy: 0.6471
# Epoch 36/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6427 - accuracy: 0.6611 - val_loss: 0.6555 - val_accuracy: 0.6471
# Epoch 37/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6426 - accuracy: 0.6611 - val_loss: 0.6500 - val_accuracy: 0.6471
# Epoch 38/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6426 - accuracy: 0.6611 - val_loss: 0.6604 - val_accuracy: 0.6471
# Epoch 39/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6433 - accuracy: 0.6611 - val_loss: 0.6503 - val_accuracy: 0.6471
# Epoch 40/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6430 - accuracy: 0.6611 - val_loss: 0.6492 - val_accuracy: 0.6471
# Epoch 41/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6430 - accuracy: 0.6611 - val_loss: 0.6566 - val_accuracy: 0.6471
# Epoch 42/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6430 - accuracy: 0.6611 - val_loss: 0.6500 - val_accuracy: 0.6471
# Epoch 43/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6429 - accuracy: 0.6611 - val_loss: 0.6497 - val_accuracy: 0.6471
# Epoch 44/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6425 - accuracy: 0.6611 - val_loss: 0.6492 - val_accuracy: 0.6471
# Epoch 45/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6417 - accuracy: 0.6611 - val_loss: 0.6492 - val_accuracy: 0.6471
# Epoch 46/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6441 - accuracy: 0.6611 - val_loss: 0.6548 - val_accuracy: 0.6471
# Epoch 47/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6428 - accuracy: 0.6611 - val_loss: 0.6585 - val_accuracy: 0.6471
# Epoch 48/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6424 - accuracy: 0.6611 - val_loss: 0.6547 - val_accuracy: 0.6471
# Epoch 49/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6433 - accuracy: 0.6611 - val_loss: 0.6492 - val_accuracy: 0.6471
# Epoch 50/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6429 - accuracy: 0.6611 - val_loss: 0.6492 - val_accuracy: 0.6471
# Epoch 51/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6432 - accuracy: 0.6611 - val_loss: 0.6514 - val_accuracy: 0.6471
# Epoch 52/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6435 - accuracy: 0.6611 - val_loss: 0.6635 - val_accuracy: 0.6471
# Epoch 53/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6450 - accuracy: 0.6611 - val_loss: 0.6492 - val_accuracy: 0.6471
# Epoch 54/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6419 - accuracy: 0.6611 - val_loss: 0.6505 - val_accuracy: 0.6471
# Epoch 55/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6416 - accuracy: 0.6611 - val_loss: 0.6618 - val_accuracy: 0.6471
# Epoch 56/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6444 - accuracy: 0.6611 - val_loss: 0.6494 - val_accuracy: 0.6471
# Epoch 57/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6434 - accuracy: 0.6611 - val_loss: 0.6493 - val_accuracy: 0.6471
# Epoch 58/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6437 - accuracy: 0.6611 - val_loss: 0.6496 - val_accuracy: 0.6471
# Epoch 59/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6439 - accuracy: 0.6611 - val_loss: 0.6492 - val_accuracy: 0.6471
# Epoch 60/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6420 - accuracy: 0.6611 - val_loss: 0.6505 - val_accuracy: 0.6471
# Epoch 61/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6443 - accuracy: 0.6611 - val_loss: 0.6498 - val_accuracy: 0.6471
# Epoch 62/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6424 - accuracy: 0.6611 - val_loss: 0.6494 - val_accuracy: 0.6471
# Epoch 63/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6418 - accuracy: 0.6611 - val_loss: 0.6503 - val_accuracy: 0.6471
# Epoch 64/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6418 - accuracy: 0.6611 - val_loss: 0.6496 - val_accuracy: 0.6471
# Epoch 65/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6443 - accuracy: 0.6611 - val_loss: 0.6500 - val_accuracy: 0.6471
# Epoch 66/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6459 - accuracy: 0.6611 - val_loss: 0.6500 - val_accuracy: 0.6471
# Epoch 67/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6450 - accuracy: 0.6611 - val_loss: 0.6573 - val_accuracy: 0.6471
# Epoch 68/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6443 - accuracy: 0.6611 - val_loss: 0.6512 - val_accuracy: 0.6471
# Epoch 69/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6429 - accuracy: 0.6611 - val_loss: 0.6500 - val_accuracy: 0.6471
# Epoch 70/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6435 - accuracy: 0.6611 - val_loss: 0.6503 - val_accuracy: 0.6471
# Epoch 71/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6421 - accuracy: 0.6611 - val_loss: 0.6497 - val_accuracy: 0.6471
# Epoch 72/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6437 - accuracy: 0.6611 - val_loss: 0.6496 - val_accuracy: 0.6471
# Epoch 73/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6439 - accuracy: 0.6611 - val_loss: 0.6495 - val_accuracy: 0.6471
# Epoch 74/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6424 - accuracy: 0.6611 - val_loss: 0.6505 - val_accuracy: 0.6471
# Epoch 75/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6422 - accuracy: 0.6611 - val_loss: 0.6494 - val_accuracy: 0.6471
# Epoch 76/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6449 - accuracy: 0.6611 - val_loss: 0.6506 - val_accuracy: 0.6471
# Epoch 77/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6430 - accuracy: 0.6611 - val_loss: 0.6511 - val_accuracy: 0.6471
# Epoch 78/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6451 - accuracy: 0.6611 - val_loss: 0.6493 - val_accuracy: 0.6471
# Epoch 79/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6428 - accuracy: 0.6611 - val_loss: 0.6507 - val_accuracy: 0.6471
# Epoch 80/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6440 - accuracy: 0.6611 - val_loss: 0.6502 - val_accuracy: 0.6471
# Epoch 81/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6409 - accuracy: 0.6611 - val_loss: 0.6521 - val_accuracy: 0.6471
# Epoch 82/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6441 - accuracy: 0.6611 - val_loss: 0.6544 - val_accuracy: 0.6471
# Epoch 83/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6422 - accuracy: 0.6611 - val_loss: 0.6493 - val_accuracy: 0.6471
# Epoch 84/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6431 - accuracy: 0.6611 - val_loss: 0.6501 - val_accuracy: 0.6471
# Epoch 85/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6427 - accuracy: 0.6611 - val_loss: 0.6605 - val_accuracy: 0.6471
# Epoch 86/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6428 - accuracy: 0.6611 - val_loss: 0.6518 - val_accuracy: 0.6471
# Epoch 87/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6412 - accuracy: 0.6611 - val_loss: 0.6552 - val_accuracy: 0.6471
# Epoch 88/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6436 - accuracy: 0.6611 - val_loss: 0.6517 - val_accuracy: 0.6471
# Epoch 89/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6428 - accuracy: 0.6611 - val_loss: 0.6506 - val_accuracy: 0.6471
# Epoch 90/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6417 - accuracy: 0.6611 - val_loss: 0.6492 - val_accuracy: 0.6471
# Epoch 91/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6439 - accuracy: 0.6611 - val_loss: 0.6499 - val_accuracy: 0.6471
# Epoch 92/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6433 - accuracy: 0.6611 - val_loss: 0.6529 - val_accuracy: 0.6471
# Epoch 93/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6427 - accuracy: 0.6611 - val_loss: 0.6494 - val_accuracy: 0.6471
# Epoch 94/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6427 - accuracy: 0.6611 - val_loss: 0.6554 - val_accuracy: 0.6471
# Epoch 95/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6430 - accuracy: 0.6611 - val_loss: 0.6493 - val_accuracy: 0.6471
# Epoch 96/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6435 - accuracy: 0.6611 - val_loss: 0.6545 - val_accuracy: 0.6471
# Epoch 97/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6431 - accuracy: 0.6611 - val_loss: 0.6565 - val_accuracy: 0.6471
# Epoch 98/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6434 - accuracy: 0.6611 - val_loss: 0.6505 - val_accuracy: 0.6471
# Epoch 99/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6428 - accuracy: 0.6611 - val_loss: 0.6521 - val_accuracy: 0.6471
# Epoch 100/100
# 96/96 [==============================] - 0s 2ms/step - loss: 0.6432 - accuracy: 0.6611 - val_loss: 0.6540 - val_accuracy: 0.6471

# %% [markdown]
# <h2>SVM Classifer<h2>

# %%
def train_svm(X_train, y_train, X_val, y_val):
    def svm_eval(C, gamma):
        # Define SVM with hyperparameters
        svm = SVC(kernel='rbf', C=C, gamma=gamma)

        # Train on training data
        svm.fit(X_train, y_train)

        # Predict on validation data
        y_pred = svm.predict(X_val)

        # Compute accuracy
        accuracy = accuracy_score(y_val, y_pred)
        return accuracy

    def optimize_svm(X_train, y_train, X_val, y_val):
        # Define the bounds of the hyperparameters
        pbounds = {'C': (0.1, 100), 'gamma': (0.0001, 0.1)}

        # Instantiate Bayesian Optimization
        optimizer = BayesianOptimization(f=svm_eval, pbounds=pbounds, random_state=1)

        # Maximize the accuracy
        optimizer.maximize(init_points=10, n_iter=20)

        return optimizer.max['params']
    
    # Hyperparameter tuning
    best_params = optimize_svm(X_train, y_train, X_val, y_val)
    best_C = best_params['C']
    best_gamma = best_params['gamma']

    # Train SVM with the best parameters
    svm = SVC(kernel='rbf', C=best_C, gamma=best_gamma)
    svm.fit(X_train, y_train)

    # Validate
    y_pred = svm.predict(X_val)
    return y_pred

# %% [markdown]
# <h2>SVM Testing</h2>

# %%
X_train, X_test, y_train, y_test = train_test_split(all_images, all_labels, test_size=0.2, random_state=42)

X_train_flattened = np.array([image.flatten() for image in X_train])
X_test_flattened = np.array([image.flatten() for image in X_test])


y_pred = train_svm(X_train_flattened, y_train, X_test_flattened, y_test)

# Evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)

print(f"Accuracy: {accuracy}, Recall: {recall}, Precision: {precision}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Yo200\Downloads\DL Project\Manual Extraction Real2.ipynb Cell 23 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Yo200/Downloads/DL%20Project/Manual%20Extraction%20Real2.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> X_train, X_test, y_train, y_test = train_test_split(all_images, all_labels, test_size=0.2, random_state=42)
#       <a href='vscode-notebook-cell:/c%3A/Users/Yo200/Downloads/DL%20Project/Manual%20Extraction%20Real2.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a> X_train_flattened = np.array([image.flatten() for image in X_train])
#       <a href='vscode-notebook-cell:/c%3A/Users/Yo200/Downloads/DL%20Project/Manual%20Extraction%20Real2.ipynb#X31sZmlsZQ%3D%3D?line=3'>4</a> X_test_flattened = np.array([image.flatten() for image in X_test])
#
# NameError: name 'all_images' is not defined
